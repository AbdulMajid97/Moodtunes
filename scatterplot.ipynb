# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
df= pd.read_csv("C:\\Users\\Majid\\Programming Files\\FYP\Datasets\\EMO_Dataset\\annotations\\static_annotations.csv")

# %%
df
# Out:
#      song_id  mean_arousal  std_arousal  mean_valence  std_valence
# 0          2        3.1000      0.99443        3.0000      0.66667
# 1          3        3.5000      1.84090        3.3000      1.70290
# 2          4        5.7000      1.49440        5.5000      1.71590
# 3          5        4.4000      2.11870        5.3000      1.94650
# 4          7        5.8000      1.54920        6.4000      1.77640
# ..       ...           ...          ...           ...          ...
# 739      995        4.7000      1.33750        2.4000      0.96609
# 740      996        6.0000      1.69970        6.7000      1.76700
# 741      997        6.4000      2.22110        6.7000      1.76700
# 742      999        4.1000      2.42440        5.9000      1.66330
# 743     1000        7.2222      1.09290        5.8889      2.08830
#
# [744 rows x 5 columns]

# %%
plt.scatter(df['mean_arousal'], df['mean_valence'])
plt.xlabel('Mean Arousal')
plt.ylabel('Mean Valence')
plt.title('Scatter Plot of Mean Arousal vs Mean Valence')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Mean Arousal vs Mean Valence')

# %%
# Select the features for clustering
features = ['mean_arousal', 'mean_valence']
X = df[features]

# Apply K-means clustering
k = 3  # Number of clusters
kmeans = KMeans(n_clusters=k, random_state=42)
kmeans.fit(X)
# Out:
# C:\Users\Majid\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
df['cluster']= kmeans.labels_

# %%
# Scatter plot with cluster colors
plt.scatter(df['mean_arousal'], df['mean_valence'], c=df['cluster'], cmap='viridis')
plt.xlabel('Mean Arousal')
plt.ylabel('Mean Valence')
plt.title('Clustering of Mean Arousal vs Mean Valence')

# Add data labels
for i in range(len(df)):
    plt.text(df['mean_arousal'][i], df['mean_valence'][i], df['song_id'][i])

# Show the plot
plt.show()
